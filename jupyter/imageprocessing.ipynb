# %%
import numpy as np
import imgaug as ia
import imageio
import imgaug.augmenters as iaa
import cv2
# %matplotlib inline

# %%
# Link Google Drive files

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
image = imageio.imread("/content/drive/My Drive/Colab Notebooks/shrew_emesis/retch-lms-2021-10-25/Images/shrew1_img21869.png")
ia.imshow(image)

# %%
#Images scaled
img_scaled = cv2.resize(image, (300,300))
ia.imshow(img_scaled)

# %%
ia.seed(4)

rotate = iaa.Affine(rotate=(-25, 25))
image_aug = rotate(image=img_scaled)

print("Augmented:")
ia.imshow(image_aug)
# Out:
# Augmented:

# %% [markdown]
# Contrast
# 1. histeq
# 2. clahe
# 3. gamma
# 4. sigmoid
# 5. log
# 6. lineaer
#
# Convolution
# 1. sharpen
# 2. emboss
# 3. edge

# %%
contrast_aug = ["histeq", "clahe", "gamma", "sigmoid", "log", "linear"]
i=0
for i in range(0,len(contrast_aug)):
  print(i)

# seq = iaa.Sequential([
                      # iaa.AllChannelsHistogramEqualization("histeq"),
                      # iaa.AllChannelsHistogramEqualization("clahe"),
                      # iaa.AllChannelsHistogramEqualization("gamma"),
                      # iaa.
# ])

# images_aug = seq(images=img_scaled)
# ia.imshow(images_aug)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.MotionBlur(k=7, angle=[-90, 90]),
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05 * 255), per_channel=0.5),
    iaa.CoarseDropout(0.02, size_percent=0.3, per_channel=0.5),
    iaa.ElasticTransformation(sigma=5)
], random_order=True)

images_aug = seq(images=img_scaled)
ia.imshow(images_aug)
